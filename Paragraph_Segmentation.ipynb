# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopalkushwaha1/ML_Intern/blob/main/Paragraph_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract opencv-python Pillow

# %% [markdown]
# # Importing library

# %%
import cv2
import pytesseract
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# #Load the Image

# %%
# image_path = "img2.jpg"
# image = cv2.imread(image_path)

# plt.figure(figsize=(5, 5))
# plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
# plt.title('Original Image')
# plt.show()

# %%
image_path = "img3.jpg"
image = cv2.imread(image_path)

plt.figure(figsize=(5, 5))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.show()

# %% [markdown]
# # Change to gray Scale

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(5, 5))
plt.imshow(gray, cmap='gray')
plt.title('Gray Scale Image')
plt.show()

# %% [markdown]
# # Apply Threshold

# %%
 _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)

plt.figure(figsize=(5, 5))
plt.imshow(thresh, cmap='gray')
plt.title('Thresholded Image')
plt.show()

# %%
# _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)

_, thresh = cv2.threshold(gray, 100, 255, cv2.THRESH_BINARY_INV)

plt.figure(figsize=(5, 5))
plt.imshow(thresh, cmap='gray')
plt.title('Thresholded Image')
plt.show()

# %% [markdown]
# # Apply OCR

# %%
ocr_data = pytesseract.image_to_data(thresh, output_type=pytesseract.Output.DICT)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('OCR Data')
plt.show()

# %% [markdown]
# # Make Retrangle to paragraph

# %%
n_boxes = len(ocr_data['level'])
for i in range(n_boxes):
    if ocr_data['level'][i] == 3:
        (x, y, w, h) = (ocr_data['left'][i], ocr_data['top'][i], ocr_data['width'][i], ocr_data['height'][i])
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 5)

# %% [markdown]
# # Result

# %%
plt.figure(figsize=(5, 5))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Result Paragraph Segmentation')
plt.show()
